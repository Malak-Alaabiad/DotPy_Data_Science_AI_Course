# %% [markdown]
# # Insurance Data
# I have the age, sex, bmi, If the person has children or not and them number, the region in ehich he lives and the charges, and if the person smokes or not.
#
# I want to know his\her charges?

# %%
import pandas as pd
data = pd.read_csv('/content/insurance.csv')
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr = x.corr()
sns.heatmap(corr, annot = True, cmap='coolwarm')
plt.show()
# Out:
# <ipython-input-144-c58c6e6064e3>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = x.corr()

# %% [markdown]
# # Data insights

# %%
data_frame1 = data[['charges', 'smoker']]

# %%
data_frame1.groupby('smoker').mean()
# Out:
#              charges
# smoker
# no       8440.660307
# yes     32050.231832

# %%
data_frame1.groupby('smoker').max()
# Out:
#             charges
# smoker
# no      36910.60803
# yes     63770.42801

# %%
data_frame1.groupby('smoker').min()
# Out:
#            charges
# smoker
# no       1121.8739
# yes     12829.4551

# %%
data['bmi'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 1333    30.970
# 1334    31.920
# 1335    36.850
# 1336    25.800
# 1337    29.070
# Name: bmi, Length: 1337, dtype: float64>

# %%
def bmicat(bmi):
  if bmi > 30.6:
    return 'overweight'
  elif bmi <= 30.6:
    return 'leastweight'

# %%
data['bmi class'] = data['bmi'].apply(bmicat)

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker      charges    bmi class
# 0   19  female  27.900         0    yes  16884.92400  leastweight
# 1   18    male  33.770         1     no   1725.55230   overweight
# 2   28    male  33.000         3     no   4449.46200   overweight
# 3   33    male  22.705         0     no  21984.47061  leastweight
# 4   32    male  28.880         0     no   3866.85520  leastweight

# %%
data_frame2 = data[['bmi class', 'charges']]

# %%
data_frame2.groupby('bmi class').mean()
# Out:
#                   charges
# bmi class
# leastweight  10920.738231
# overweight   15801.788406

# %%
data = data.drop(['region'], axis = 1)

# %%
 data['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
data['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
data['age'].value_counts()
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
data['age'].unique()
# Out:
# array([19, 18, 28, 33, 32, 31, 46, 37, 60, 25, 62, 23, 56, 27, 52, 30, 34,
#        59, 63, 55, 22, 26, 35, 24, 41, 38, 36, 21, 48, 40, 58, 53, 43, 64,
#        20, 61, 44, 57, 29, 45, 54, 49, 47, 51, 42, 50, 39])

# %%
new_data = data[['age','sex','children','smoker']]

# %%
new_data.head()
# Out:
#    age     sex  children smoker
# 0   19  female         0    yes
# 1   18    male         1     no
# 2   28    male         3     no
# 3   33    male         0     no
# 4   32    male         0     no

# %%
new_data.groupby('smoker').mean()
# Out:
# <ipython-input-9-84ebd5f4af44>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_data.groupby('smoker').mean()
#               age  children
# smoker
# no      39.385338  1.090226
# yes     38.514599  1.113139

# %%
x['smoker'] = x['smoker'].replace(['yes','no'],[1,0])

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker      charges    bmi class
# 0   19    1  27.900         0       1  16884.92400  leastweight
# 1   18    0  33.770         1       0   1725.55230   overweight
# 2   28    0  33.000         3       0   4449.46200   overweight
# 3   33    0  22.705         0       0  21984.47061  leastweight
# 4   32    0  28.880         0       0   3866.85520  leastweight

# %%
def convert(c):
  if c == 'southeast':
    return 1
  elif c == 'southwest':
    return 2
  elif c == 'northwest':
    return 3
  elif c == 'northeast':
    return 4

# %%
data['region'] = data['region'].apply(convert)

# %%
data.head()
# Out:
#    age     sex     bmi  children  smoker  region      charges
# 0   19  female  27.900         0       1       2  16884.92400
# 1   18    male  33.770         1       0       1   1725.55230
# 2   28    male  33.000         3       0       1   4449.46200
# 3   33    male  22.705         0       0       3  21984.47061
# 4   32    male  28.880         0       0       3   3866.85520

# %%
x['sex'] = x['sex'].replace(['male','female'],[0,1])

# %%
data
# Out:
#       age  sex     bmi  children smoker      charges    bmi class
# 0      19    1  27.900         0    yes  16884.92400  leastweight
# 1      18    0  33.770         1     no   1725.55230   overweight
# 2      28    0  33.000         3     no   4449.46200   overweight
# 3      33    0  22.705         0     no  21984.47061  leastweight
# 4      32    0  28.880         0     no   3866.85520  leastweight
# ...   ...  ...     ...       ...    ...          ...          ...
# 1333   50    0  30.970         3     no  10600.54830   overweight
# 1334   18    1  31.920         0     no   2205.98080   overweight
# 1335   18    1  36.850         0     no   1629.83350   overweight
# 1336   21    1  25.800         0     no   2007.94500  leastweight
# 1337   61    1  29.070         0    yes  29141.36030  leastweight
#
# [1337 rows x 7 columns]

# %% [markdown]
# # Data Understanding

# %% [markdown]
# 1 ) Remove all messing values

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (1337, 7)

# %%
data = data.drop_duplicates()

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       1       2  16884.92400
# 1   18    0  33.770         1       0       1   1725.55230
# 2   28    0  33.000         3       0       1   4449.46200
# 3   33    0  22.705         0       0       3  21984.47061
# 4   32    0  28.880         0       0       3   3866.85520

# %%
data['age'] = data['age'].astype(int)

# %%
data['bmi'] = data['bmi'].astype(float)

# %%
data['charges'] = data['charges'].astype(float)

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       1       2  16884.92400
# 1   18    0  33.770         1       0       1   1725.55230
# 2   28    0  33.000         3       0       1   4449.46200
# 3   33    0  22.705         0       0       3  21984.47061
# 4   32    0  28.880         0       0       3   3866.85520

# %%
y = data.iloc[:, 5:6]
y.head()
# Out:
#       region
# 0  southwest
# 1  southeast
# 2  southeast
# 3  northwest
# 4  northwest

# %%
x = data.iloc[:, :5]
x.head()
# Out:
#    age     sex     bmi  children smoker
# 0   19  female  27.900         0    yes
# 1   18    male  33.770         1     no
# 2   28    male  33.000         3     no
# 3   33    male  22.705         0     no
# 4   32    male  28.880         0     no

# %%
x = pd.get_dummies(x)
x.head()
# Out:
#    age     bmi  children  sex_female  sex_male  smoker_no  smoker_yes
# 0   19  27.900         0           1         0          0           1
# 1   18  33.770         1           0         1          1           0
# 2   28  33.000         3           0         1          1           0
# 3   33  22.705         0           0         1          1           0
# 4   32  28.880         0           0         1          1           0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()
x = scaler_x.fit_transform(x)
y = scaler_y.fit_transform(y)

# %%
x
# Out:
# array([[0.02173913, 1.        , 0.3212268 , 0.        , 1.        ],
#        [0.        , 0.        , 0.47914985, 0.2       , 0.        ],
#        [0.2173913 , 0.        , 0.45843422, 0.6       , 0.        ],
#        ...,
#        [0.        , 1.        , 0.56201238, 0.        , 0.        ],
#        [0.06521739, 1.        , 0.26472962, 0.        , 0.        ],
#        [0.93478261, 1.        , 0.35270379, 0.        , 1.        ]])

# %%
data
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       1       2  16884.92400
# 1      18    0  33.770         1       0       1   1725.55230
# 2      28    0  33.000         3       0       1   4449.46200
# 3      33    0  22.705         0       0       3  21984.47061
# 4      32    0  28.880         0       0       3   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    0  30.970         3       0       3  10600.54830
# 1334   18    1  31.920         0       0       4   2205.98080
# 1335   18    1  36.850         0       0       1   1629.83350
# 1336   21    1  25.800         0       0       2   2007.94500
# 1337   61    1  29.070         0       1       3  29141.36030
#
# [1337 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %% [markdown]
# # AI

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train, y_train)
# Out:
# 0.7446502231101064

# %%
model.score(x_test, y_test)
# Out:
# 0.7633932657459425

# %%
x
# Out:
#       age  sex     bmi  children  smoker
# 0      19    1  27.900         0       1
# 1      18    0  33.770         1       0
# 2      28    0  33.000         3       0
# 3      33    0  22.705         0       0
# 4      32    0  28.880         0       0
# ...   ...  ...     ...       ...     ...
# 1333   50    0  30.970         3       0
# 1334   18    1  31.920         0       0
# 1335   18    1  36.850         0       0
# 1336   21    1  25.800         0       0
# 1337   61    1  29.070         0       1
#
# [1337 rows x 5 columns]

# %%
from sklearn.svm import SVR
model2 = SVR(kernel= 'linear', C = 1)

# %%
model2.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=1, kernel='linear')

# %%
model2.score(x_train, y_train)
# Out:
# 0.7289463335691493

# %%
model2.score(x_test, y_test)
# Out:
# 0.7555728366707387

# %%
from sklearn.tree import DecisionTreeRegressor
model3 = DecisionTreeRegressor()
model3.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
model3.score(x_train, y_train)
# Out:
# 0.9994785051939724

# %%
model3.score(x_test, y_test)
# Out:
# 0.7258607000050132

# %%
from sklearn.ensemble import RandomForestRegressor
model4 = RandomForestRegressor(n_estimators=270)
model4.fit(x_train, y_train)
# Out:
# <ipython-input-132-68043356b4a5>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model4.fit(x_train, y_train)
# RandomForestRegressor(n_estimators=270)

# %%
model4.score(x_train, y_train)
# Out:
# 0.9760267581969881

# %%
model4.score(x_test, y_test)
# Out:
# 0.8393985336423532

# %%
from xgboost import XGBRegressor
model5 = XGBRegressor(n_estimators=170)
model5.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=170, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
model5.score(x_train, y_train)
# Out:
# 0.9984351250149932

# %%
model5.score(x_test, y_test)
# Out:
# 0.8084116981974703
