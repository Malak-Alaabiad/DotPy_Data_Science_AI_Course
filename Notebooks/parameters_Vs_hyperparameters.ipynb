# %% [markdown]
# # hyperparameter Tuning
# one reasin of the bad accuracy of the model could be features or dara size or bad algorithism or the data is imbalanced or ***the specification of the the hperparameters!!!!!!!!!!!!***
#
# #parameters Vs hyperparameters
# parameters are fixed and they are the weights generated by the algorithism however hyper parameters is changing parameters related to the features and the specification of the algorithism
#
# #search algorthims
# SVM for example have c which is the sixe of the margin in the data to be taken into consideration
#  and kernal that determines the type of the fit whether it is linear or qudartic(polynomial) or rpf...etc
#   there are 2 types of search algorithim that fits with large number of combination of hyperparameters and limited number of combinations
#
#   1. Grid search which is for small number of combinations of parameters
#   2. randomized search which allows for a number of pre determined iterations for very lagre number of cominations of parameters
# #Deep learning
# this type of machine learnig is used when the number of features is exteremly large
# deep learning is so powerful that is used only for complex models and if used with simple model it tends to overfit the model

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Churn_Modelling.csv')

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
x = data.iloc[ : , 3:13]

# %%
y = data.iloc[ : , 13:14 ]

# %%
y
# Out:
#       Exited
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# 9999       0
#
# [10000 rows x 1 columns]

# %%
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
x['Gender'] = data['Gender'].replace(['Female' , 'Male'] , [1,0])

# %%
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France       1   42       2       0.00              1
# 1             608     Spain       1   41       1   83807.86              1
# 2             502    France       1   42       8  159660.80              3
# 3             699    France       1   39       1       0.00              2
# 4             850     Spain       1   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France       0   39       5       0.00              2
# 9996          516    France       0   35      10   57369.61              1
# 9997          709    France       1   36       7       0.00              1
# 9998          772   Germany       0   42       3   75075.31              2
# 9999          792    France       1   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
x = pd.get_dummies(x)

# %%
x
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       1   42       2       0.00              1          1
# 1             608       1   41       1   83807.86              1          0
# 2             502       1   42       8  159660.80              3          1
# 3             699       1   39       1       0.00              2          0
# 4             850       1   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771       0   39       5       0.00              2          1
# 9996          516       0   35      10   57369.61              1          1
# 9997          709       1   36       7       0.00              1          0
# 9998          772       0   42       3   75075.31              2          1
# 9999          792       1   28       4  130142.79              1          1
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
x = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x , y , test_size = 0.2)

# %% [markdown]
# # Machine Learning
#
# 1. SVM
# 2. XGboost
#
# lets try our hyper parameters using tools of tuning, the hyper parameters og machine learning are C and kernal

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.svm import SVC
model = SVC()

# %%
ParameterGrid = {
    'C' : [0.1, 1, 10],
    'kernel': ['rbf', 'linear', 'sigmoid']
}

# %%
grid = GridSearchCV (model, ParameterGrid)

# %% [markdown]
# #Deep learning

# %%
#Deeplearning model
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd

# %%
model = Sequential([
    Dense (units = 7 , activation = 'relu'), # no input layer
    Dense (units = 7 , activation = 'relu'),
    Dense (units = 7 , activation = 'relu'),
    Dense (units = 1 , activation = 'sigmoid') #output layer
])

# %%
from keras.optimizers import AdamW

# %%
opt = AdamW(learning_rate= 0.01)

# %%
model.compile( optimizer = opt , loss = 'binary_crossentropy' , metrics = ['accuracy'])

# %%
history = model.fit(x_train, y_train , batch_size = 20 , epochs = 15)
# Out:
# Epoch 1/15
# 400/400 [==============================] - 2s 2ms/step - loss: 0.4545 - accuracy: 0.8018
# Epoch 2/15
# 400/400 [==============================] - 1s 2ms/step - loss: 0.4207 - accuracy: 0.8266
# Epoch 3/15
# 400/400 [==============================] - 1s 2ms/step - loss: 0.4095 - accuracy: 0.8317
# Epoch 4/15
# 400/400 [==============================] - 1s 2ms/step - loss: 0.4095 - accuracy: 0.8306
# Epoch 5/15
# 400/400 [==============================] - 1s 2ms/step - loss: 0.4033 - accuracy: 0.8356
# Epoch 6/15
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3984 - accuracy: 0.8380
# Epoch 7/15
# 400/400 [==============================] - 1s 3ms/step - loss: 0.3965 - accuracy: 0.8404
# Epoch 8/15
# 400/400 [==============================] - 1s 2ms/step - loss: 0.3939 - accuracy: 0.8431
# Epoch 9/15
# 400/400 [==============================] - 1s 2ms/step - loss: 0.3931 - accuracy: 0.8397
# Epoch 10/15
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history["accuracy"])
plt.show()
