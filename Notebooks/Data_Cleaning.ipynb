# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Data.csv')
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data.head()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
data.tail()
# Out:
#    Country   Age   Salary Purchased
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data.sample(3)
# Out:
#    Country   Age   Salary Purchased
# 7   France  48.0  79000.0       Yes
# 2  Germany  30.0  54000.0        No
# 6    Spain   NaN  52000.0        No

# %% [markdown]
# ***Indexing:***
#
# ---

# %%
data['Salary']
# Out:
# 0    72000.0
# 1    48000.0
# 2    54000.0
# 3    61000.0
# 4        NaN
# 5    58000.0
# 6    52000.0
# 7    79000.0
# 8    83000.0
# 9    67000.0
# Name: Salary, dtype: float64

# %%
features = data.iloc[ : , 0:3]
features
# Out:
#    Country   Age   Salary
# 0   France  44.0  72000.0
# 1    Spain  27.0  48000.0
# 2  Germany  30.0  54000.0
# 3    Spain  38.0  61000.0
# 4  Germany  40.0      NaN
# 5   France  35.0  58000.0
# 6    Spain   NaN  52000.0
# 7   France  48.0  79000.0
# 8  Germany  50.0  83000.0
# 9   France  37.0  67000.0

# %%
label = data.iloc[ : , 3:4]
label
# Out:
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5       Yes
# 6        No
# 7       Yes
# 8        No
# 9       Yes

# %%
data[['Salary','Country']]
# Out:
#     Salary  Country
# 0  72000.0   France
# 1  48000.0    Spain
# 2  54000.0  Germany
# 3  61000.0    Spain
# 4      NaN  Germany
# 5  58000.0   France
# 6  52000.0    Spain
# 7  79000.0   France
# 8  83000.0  Germany
# 9  67000.0   France

# %% [markdown]
# Data Updating

# %%
data['Updated Salary'] = data['Salary'] * 1.3

# %%
data
# Out:
#    Country   Age   Salary Purchased  Updated Salary
# 0   France  44.0  72000.0        No         93600.0
# 1    Spain  27.0  48000.0       Yes         62400.0
# 2  Germany  30.0  54000.0        No         70200.0
# 3    Spain  38.0  61000.0        No         79300.0
# 4  Germany  40.0      NaN       Yes             NaN
# 5   France  35.0  58000.0       Yes         75400.0
# 6    Spain   NaN  52000.0        No         67600.0
# 7   France  48.0  79000.0       Yes        102700.0
# 8  Germany  50.0  83000.0        No        107900.0
# 9   France  37.0  67000.0       Yes         87100.0

# %%
data['Age'] = data['Age'] + 10

# %%
data
# Out:
#    Country   Age   Salary Purchased  Updated Salary
# 0   France  54.0  72000.0        No         93600.0
# 1    Spain  37.0  48000.0       Yes         62400.0
# 2  Germany  40.0  54000.0        No         70200.0
# 3    Spain  48.0  61000.0        No         79300.0
# 4  Germany  50.0      NaN       Yes             NaN
# 5   France  45.0  58000.0       Yes         75400.0
# 6    Spain   NaN  52000.0        No         67600.0
# 7   France  58.0  79000.0       Yes        102700.0
# 8  Germany  60.0  83000.0        No        107900.0
# 9   France  47.0  67000.0       Yes         87100.0

# %%
data['Country'].value_counts()
# Out:
# France     4
# Spain      3
# Germany    3
# Name: Country, dtype: int64

# %%
data['Purchased'].value_counts()
# Out:
# No     5
# Yes    5
# Name: Purchased, dtype: int64

# %%
data['Country'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
new_data = data[['Age', 'Purchased']]
new_data
# Out:
#     Age Purchased
# 0  54.0        No
# 1  37.0       Yes
# 2  40.0        No
# 3  48.0        No
# 4  50.0       Yes
# 5  45.0       Yes
# 6   NaN        No
# 7  58.0       Yes
# 8  60.0        No
# 9  47.0       Yes

# %%
new_data.groupby('Purchased').mean()
# Out:
#             Age
# Purchased
# No         50.5
# Yes        47.4

# %%
data2 = data[['Country','Salary']]

# %%
data2.groupby('Country').mean()
# Out:
#                Salary
# Country
# France   69000.000000
# Germany  68500.000000
# Spain    53666.666667

# %%
data['Purchased'] = data['Purchased'].replace(['Yes','No'],[ 1, 0])
data
# Out:
#    Country   Age   Salary  Purchased  Updated Salary
# 0   France  54.0  72000.0          0         93600.0
# 1    Spain  37.0  48000.0          1         62400.0
# 2  Germany  40.0  54000.0          0         70200.0
# 3    Spain  48.0  61000.0          0         79300.0
# 4  Germany  50.0      NaN          1             NaN
# 5   France  45.0  58000.0          1         75400.0
# 6    Spain   NaN  52000.0          0         67600.0
# 7   France  58.0  79000.0          1        102700.0
# 8  Germany  60.0  83000.0          0        107900.0
# 9   France  47.0  67000.0          1         87100.0

# %%
data['Country'] = data['Country'].replace(['France','Spain','Germany'],[1 , 2, 3])
data
# Out:
#    Country   Age   Salary  Purchased  Updated Salary
# 0        1  54.0  72000.0          0         93600.0
# 1        2  37.0  48000.0          1         62400.0
# 2        3  40.0  54000.0          0         70200.0
# 3        2  48.0  61000.0          0         79300.0
# 4        3  50.0      NaN          1             NaN
# 5        1  45.0  58000.0          1         75400.0
# 6        2   NaN  52000.0          0         67600.0
# 7        1  58.0  79000.0          1        102700.0
# 8        3  60.0  83000.0          0        107900.0
# 9        1  47.0  67000.0          1         87100.0

# %%
import pandas as pd
data = pd.read_csv('/content/Data.csv')
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
def convert(c):
  if c == "France":
    return 1
  elif c == "Spain":
    return 2
  elif c == "Germany":
    return 3

# %%
data['Country'] = data['Country'].apply(convert)
data
# Out:
#    Country   Age   Salary Purchased
# 0        1  44.0  72000.0        No
# 1        2  27.0  48000.0       Yes
# 2        3  30.0  54000.0        No
# 3        2  38.0  61000.0        No
# 4        3  40.0      NaN       Yes
# 5        1  35.0  58000.0       Yes
# 6        2   NaN  52000.0        No
# 7        1  48.0  79000.0       Yes
# 8        3  50.0  83000.0        No
# 9        1  37.0  67000.0       Yes

# %%
data = pd.read_csv('/content/Data.csv')
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data = data.dropna()
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data.shape
# Out:
# (8, 4)

# %%
data = data.drop_duplicates()
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data.shape
# Out:
# (8, 4)

# %%
features = data.iloc[:,0:3]
labels = data.iloc[:, 3:4]
features
labels
# Out:
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5       Yes
# 6        No
# 7       Yes
# 8        No
# 9       Yes

# %%
print(features)
# Out:
#    Country   Age   Salary
# 0   France  44.0  72000.0
# 1    Spain  27.0  48000.0
# 2  Germany  30.0  54000.0
# 3    Spain  38.0  61000.0
# 5   France  35.0  58000.0
# 7   France  48.0  79000.0
# 8  Germany  50.0  83000.0
# 9   France  37.0  67000.0

# %%
print(labels)
# Out:
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5       Yes
# 6        No
# 7       Yes
# 8        No
# 9       Yes

# %%
features = pd.get_dummies(features)
features
# Out:
#     Age   Salary  Country_France  Country_Germany  Country_Spain
# 0  44.0  72000.0               1                0              0
# 1  27.0  48000.0               0                0              1
# 2  30.0  54000.0               0                1              0
# 3  38.0  61000.0               0                0              1
# 4  40.0      NaN               0                1              0
# 5  35.0  58000.0               1                0              0
# 6   NaN  52000.0               0                0              1
# 7  48.0  79000.0               1                0              0
# 8  50.0  83000.0               0                1              0
# 9  37.0  67000.0               1                0              0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
features = scaler.fit_transform(features)
features
# Out:
# array([[0.73913043, 0.68571429, 1.        , 0.        , 0.        ],
#        [0.        , 0.        , 0.        , 0.        , 1.        ],
#        [0.13043478, 0.17142857, 0.        , 1.        , 0.        ],
#        [0.47826087, 0.37142857, 0.        , 0.        , 1.        ],
#        [0.56521739,        nan, 0.        , 1.        , 0.        ],
#        [0.34782609, 0.28571429, 1.        , 0.        , 0.        ],
#        [       nan, 0.11428571, 0.        , 0.        , 1.        ],
#        [0.91304348, 0.88571429, 1.        , 0.        , 0.        ],
#        [1.        , 1.        , 0.        , 1.        , 0.        ],
#        [0.43478261, 0.54285714, 1.        , 0.        , 0.        ]])
